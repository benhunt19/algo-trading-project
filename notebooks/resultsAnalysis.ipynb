# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
sns.set_theme(style="darkgrid")

# %%
RESULTS_FOLDER = '../data/results'

# %%
garch_df = pd.read_csv(f'{RESULTS_FOLDER}/portfolio_garch.csv')
gam_df = pd.read_csv(f'{RESULTS_FOLDER}/portfolio_gam.csv')
buy_n_hold_df = pd.read_csv(f'{RESULTS_FOLDER}/portfolio_buy_n_hold.csv')
dfs = [garch_df, gam_df, buy_n_hold_df]

# %%
actual = pd.read_csv(f'../data/SPTL_2023.csv')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 1. Delta Vt
col = 'PnL'

fig, axes = plt.subplots(3, 1, figsize=(15, 10))
titles = ['GARCH','GAM', 'Buy & Hold', ]
colors = ['blue', 'green', 'orange']

dates = pd.to_datetime(actual['date_string'])

for i, (df, title) in enumerate(zip(dfs, titles)):
    deltaVt = df[col]
    deltaVt.dropna()
    # Set monthly ticks on x-axis
    axes[i].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    plt.setp(axes[i].xaxis.get_majorticklabels(), rotation=30)
    axes[i].plot(dates, deltaVt, color=colors[i])
    mean_deltaVt = deltaVt.mean()
    axes[i].axhline(y=mean_deltaVt, color='r', linestyle='--')
    axes[i].set_title(f'$\Delta V_t$ - {title}')
    axes[i].legend(['$\Delta V_t$', f'Mean = {int(mean_deltaVt)}'])
    axes[i].set_ylabel('$\Delta V_t$ (\$)')
    axes[i].set_xlabel('Date')
    
plt.tight_layout()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:20: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\3842129585.py:20: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_title(f'$\Delta V_t$ - {title}')
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\3842129585.py:21: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].legend(['$\Delta V_t$', f'Mean = {int(mean_deltaVt)}'])
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\3842129585.py:22: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_ylabel('$\Delta V_t$ (\$)')

# %%
# 2. Delta Vt cap
col = 'capitalGains'
dfs_no_bnh = dfs[:2]

fig, axes = plt.subplots(2, 1, figsize=(15, 7))
titles = ['GARCH','GAM']
colors = ['blue', 'green']

dates = pd.to_datetime(actual['date_string'])

for i, (df, title) in enumerate(zip(dfs_no_bnh, titles)):
    deltaVtCap = df[col]
    # Set monthly ticks on x-axis
    axes[i].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    plt.setp(axes[i].xaxis.get_majorticklabels(), rotation=30)
    axes[i].plot(dates, deltaVtCap, color=colors[i])
    mean_deltaVtCap = deltaVtCap.mean()
    axes[i].axhline(y=mean_deltaVtCap, color='r', linestyle='--')
    axes[i].set_title('$\Delta V^{cap}_t$ ' + title)
    axes[i].legend(['$\Delta V^{cap}_t$', f'Mean = {int(mean_deltaVtCap)}'])
    axes[i].set_ylabel('$\Delta V^{cap}_t$ (\$)')
    axes[i].set_xlabel('Date')    
    plt.tight_layout(pad=2.0)
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:20: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\4110787093.py:20: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_title('$\Delta V^{cap}_t$ ' + title)
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\4110787093.py:21: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].legend(['$\Delta V^{cap}_t$', f'Mean = {int(mean_deltaVtCap)}'])
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\4110787093.py:22: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_ylabel('$\Delta V^{cap}_t$ (\$)')

# %%
# 3. Delta Vt_total
col = 'value'

fig, axes = plt.subplots(3, 1, figsize=(15, 10))
titles = ['GARCH','GAM', 'Buy & Hold', ]
colors = ['blue', 'green', 'orange']

dates = pd.to_datetime(actual['date_string'])

for i, (df, title) in enumerate(zip(dfs, titles)):
    deltaVt = df[col] - df[col].shift(1)
    deltaVt.dropna()
    # Set monthly ticks on x-axis
    axes[i].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    plt.setp(axes[i].xaxis.get_majorticklabels(), rotation=30)
    axes[i].plot(dates, deltaVt, color=colors[i])
    mean_deltaVt = deltaVt.mean()
    axes[i].axhline(y=mean_deltaVt, color='r', linestyle='--')
    axes[i].set_title('$\Delta V^{total}_t$ ' + title)
    axes[i].legend(['$\Delta V^{total}_t$', f'Mean = {int(mean_deltaVt)}'])
    axes[i].set_ylabel('$\Delta V^{total}_t$ (\$)')
    axes[i].set_xlabel('Date')
    
plt.tight_layout()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# <>:20: SyntaxWarning: invalid escape sequence '\D'
# <>:21: SyntaxWarning: invalid escape sequence '\D'
# <>:22: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\2289647207.py:20: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_title('$\Delta V^{total}_t$ ' + title)
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\2289647207.py:21: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].legend(['$\Delta V^{total}_t$', f'Mean = {int(mean_deltaVt)}'])
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\2289647207.py:22: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_ylabel('$\Delta V^{total}_t$ (\$)')

# %%
# Cumulative Delta V
# 3. Delta Vt_total
col = 'PnL'

fig, axes = plt.subplots(3, 1, figsize=(15, 10))
titles = ['GARCH','GAM', 'Buy & Hold', ]
colors = ['blue', 'green', 'orange']

dates = pd.to_datetime(actual['date_string'])

for i, (df, title) in enumerate(zip(dfs, titles)):
    deltaVt = df[col]
    deltaVtCS = deltaVt.cumsum()
    deltaVtCS.dropna()
    # Set monthly ticks on x-axis
    axes[i].xaxis.set_major_locator(mdates.MonthLocator(interval=1))
    axes[i].xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
    plt.setp(axes[i].xaxis.get_majorticklabels(), rotation=30)
    axes[i].plot(dates, deltaVtCS, color=colors[i])
    mean_deltaVtCS = deltaVtCS.mean()
    axes[i].axhline(y=mean_deltaVtCS, color='r', linestyle='--')
    axes[i].axhline(y=0, color='black', linestyle='-', alpha=0.3)
    axes[i].set_title('$\Delta V^{total}_t$ ' + title)
    axes[i].legend(['$\Delta V^{total}_t$', f'Mean = {int(mean_deltaVtCS)}', 'Zero Returns'])
    axes[i].set_ylabel('$\Delta V^{total}_t$ (\$)')
    axes[i].set_xlabel('Date')
    
plt.tight_layout()
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# <>:25: SyntaxWarning: invalid escape sequence '\D'
# <>:23: SyntaxWarning: invalid escape sequence '\D'
# <>:24: SyntaxWarning: invalid escape sequence '\D'
# <>:25: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\1364029608.py:23: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_title('$\Delta V^{total}_t$ ' + title)
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\1364029608.py:24: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].legend(['$\Delta V^{total}_t$', f'Mean = {int(mean_deltaVtCS)}', 'Zero Returns'])
# C:\Users\benhu\AppData\Local\Temp\ipykernel_19524\1364029608.py:25: SyntaxWarning: invalid escape sequence '\D'
#   axes[i].set_ylabel('$\Delta V^{total}_t$ (\$)')
